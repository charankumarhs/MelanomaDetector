# %% [markdown]
# <a href="https://colab.research.google.com/github/charankumarhs/MelanomaDetector/blob/main/Charan_Hulmani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### Read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import PIL
import pathlib
import glob
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Sequential
import cv2
import google.colab
from google.colab import drive

# %%
print('library - ', pd.__name__,' version ' ,pd.__version__)
print('library - ',np.__name__,' version ',np.__version__)
print('library - ',sns.__name__,' version ',sns.__version__)
print('library - ',matplotlib.__name__,' version ',matplotlib.__version__)
print('library - ', sns.__name__,' version ' ,sns.__version__)
print('library - ',PIL.__name__,' version ',PIL.__version__)
print('library - ',tf.__name__,' version ',tf.__version__)
print('library - ',keras.__name__,' version ',keras.__version__)
print('library - ',cv2.__name__,' version ',cv2.__version__)
print('library - ',google.colab.__name__,' version ',google.colab.__version__)
# Out:
# library -  pandas  version  1.5.3
# library -  numpy  version  1.23.5
# library -  seaborn  version  0.12.2
# library -  matplotlib  version  3.7.1
# library -  seaborn  version  0.12.2
# library -  PIL  version  9.4.0
# library -  tensorflow  version  2.12.0
# library -  keras.api._v2.keras  version  2.12.0
# library -  cv2  version  4.7.0
# library -  google.colab  version  0.0.1a2

# %%
# mounting the google drive:
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# !ls /content/gdrive/MyDrive/UpGrad/'Skin cancer ISIC The International Skin Imaging Collaboration'/Train
# Out:
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %% [markdown]
# ### **Task 1:** Update the paths of the train and test dataset

# %%
# Defining the path for train and test images

data_dir_train = pathlib.Path("/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
print('Total files in Train directory ', len(list(data_dir_train.glob('*/*.*'))))
print('Total files in Test directory ',len(list(data_dir_test.glob('*/*.*'))))

image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print('Total jpg in Train directory ',image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print('Total jpg in Test directory ',image_count_test)
# Out:
# Total files in Train directory  2239
# Total files in Test directory  118
# Total jpg in Train directory  2239
# Total jpg in Test directory  118

# %% [markdown]
# ### **Task 2:** Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180
np.random.seed(123)
tf.random.set_seed(123)

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Training dataset with resized image (180, 180) and seed=123, Seed is set to avoid randomness in picking the data for processing.
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Validation dataset with resized image (180, 180) and seed=123, Seed is set to avoid randomness in picking the data for processing.
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list using class_names attribute of the datasets.
# class_names correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### **Task 3:** Visualize the data
# #### Visualize one instance of all the nine classes present in the dataset

# %%
# Visualize
def visualize_one_image_of_each_category(*, pData_dir_train, pClass_names):
  plt.figure(figsize=(10, 10))
  for i, class_name in enumerate(pClass_names):
    # Sort the images to makes sure, we get to see the same image every time we execute the code
    images_of_class = sorted(list(pData_dir_train.glob(class_name + '/*.jpg')))
    image = PIL.Image.open(str(images_of_class[0]))
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.resize((img_height, img_width)))
    plt.title(class_name)
    plt.axis("off")
  plt.show()
# visualize_one_image_of_each_category
visualize_one_image_of_each_category(pData_dir_train = data_dir_train, pClass_names = class_names)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### **Task 4:** Create the model
# #### CNN model, which can accurately detect 9 classes present in the dataset. Using ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 3, padding='same', activation='relu'), # padding='same', which means zero padding with original dimension is retained. To avoid the quick data loss we are using padding. Furthermore, the stride is 1 by default and we will stick with it to let the model learn every part of image
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation='relu'),
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation='relu'),
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Flatten(), # Flatten the data to feed into dense network
  layers.Dense(units = 128, activation='relu'), # dense layer with 128 neuron
  layers.Dense(units = num_classes) #  # dense layer with 9 neuron to predict 9 different categories
])

# %% [markdown]
# ### **Task 5:** Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Choosing adam optimiser and SparseCategoricalCrossentropy loss function
### We are using SparseCategoricalCrossentropy as loss function since we have loaded the images with deafault label_mode='int',
### which assigns integer numbers to each directory, which in our case is the class of images
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),# Set from_logits=True to apply softmax activation to output
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Task 6:** Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 550s 2s/step - loss: 2.0342 - accuracy: 0.2383 - val_loss: 1.9002 - val_accuracy: 0.2506
# Epoch 2/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.6946 - accuracy: 0.3761 - val_loss: 1.5670 - val_accuracy: 0.4094
# Epoch 3/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.4585 - accuracy: 0.4799 - val_loss: 1.4815 - val_accuracy: 0.4989
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3570 - accuracy: 0.5218 - val_loss: 1.5428 - val_accuracy: 0.4832
# Epoch 5/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.2200 - accuracy: 0.5664 - val_loss: 1.3719 - val_accuracy: 0.5414
# Epoch 6/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2116 - accuracy: 0.5586 - val_loss: 1.3579 - val_accuracy: 0.5459
# Epoch 7/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.0792 - accuracy: 0.6166 - val_loss: 1.5214 - val_accuracy: 0.5257
# Epoch 8/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.0284 - accuracy: 0.6440 - val_loss: 1.4949 - val_accuracy: 0.5078
# Epoch 9/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9552 - accuracy: 0.6635 - val_loss: 1.5595 - val_accuracy: 0.5324
# Epoch 10/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.8567 - accuracy: 0.6847 - val_loss: 1.6089 - val_accuracy: 0.5436
# Epoch 11/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.7336 - accuracy: 0.7372 - val_loss: 1.5633 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.7189 - accuracy: 0.7427 - val_loss: 1.6296 - val_accuracy: 0.5615
# Epoch 13/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6745 - accuracy: 0.7578 - val_loss: 1.7572 - val_accuracy: 0.5526
# Epoch 14/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6146 - accuracy: 0.7679 - val_loss: 1.9918 - val_accuracy: 0.5190
# Epoch 15/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5234 - accuracy: 0.8119 - val_loss: 2.1288 - val_accuracy: 0.5347
# Epoch 16/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4983 - accuracy: 0.8259 - val_loss: 1.9236 - val_accuracy: 0.5347
# Epoch 17/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4127 - accuracy: 0.8504 - val_loss: 2.1786 - val_accuracy: 0.4989
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4350 - accuracy: 0.8382 - val_loss: 2.1922 - val_accuracy: 0.4989
# Epoch 19/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.3911 - accuracy: 0.8560 - val_loss: 2.1394 - val_accuracy: 0.5503
# Epoch 20/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3232 - accuracy: 0.8895 - val_loss: 2.7018 - val_accuracy: 0.5302

# %% [markdown]
# ### **Task 7:** Visualizing training results

# %%
def visualize_training_results(*, phistory, pepochs):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(pepochs)

  plt.figure(figsize=(8, 8))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

# visualize_training_results
visualize_training_results(phistory = history, pepochs = epochs)

# %% [markdown]
# ### **Task 8:** Observations from the CNN model built
#
# #### The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around ~53% accuracy on the validation set. But, it has an accuracy of ~88% with training set.
#
# #### Model is clearly Overfitting
# * We can see that the accuracy of the model with training dataset is increasing over time with each epoch, reaching an accuracy of 85%+, whereas the accuracy of the validation dataset stalls around 50-55%. Furthermore, the difference between accuracy of training and validation dataset is ~30%+, which is a huge difference and the model is clearly Overfitting.
# * The overfitting in this case is most likely due to less number of images in the dataset we are giving to the model for learning and the model could be learning from noise or unwanted data.
# * Overfitting problem could be solved through data augmentation and adding dropout layers in the model.
#
#
# #### Data augmentation,  takes the approach of generating additional training data from existing images by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# #### Dropout is a regularization technique to avoid overfitting in the network. Applying a dropout to a layer will result in randomly dropping out a number of output units from the layer during the training process by setting the activation to zero.

# %% [markdown]
# ### **Task 9:** Build a model with Data augumentation strategy.

# %% [markdown]
# ### Task **9.1:** Data augumentation

# %%
# Data augumentation
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# ### **Task 9.2:**  Visualize a sample images with augmentation

# %%
# Visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### **Task 9.3:** Create the model, compile and train the model with data augmentation layer

# %%
## Model with Data Augmentation layer in the begining and adding 20% dropout after 3rd maxpooling layer

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),# adding 20% dropout to avoid overfit
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ### **Task 9.4:** Compiling the model with data augmentation layer with adam optimizer and SparseCategoricalCrossentropy lossfunction

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  outputs (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Task 9.5:** Training the model with data augmentation layer

# %%
epochs = 20
history = model.fit(
  x =  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 4s 37ms/step - loss: 2.0910 - accuracy: 0.2372 - val_loss: 1.9892 - val_accuracy: 0.2528
# Epoch 2/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.8740 - accuracy: 0.3153 - val_loss: 1.7877 - val_accuracy: 0.3736
# Epoch 3/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.7030 - accuracy: 0.3705 - val_loss: 1.7730 - val_accuracy: 0.3490
# Epoch 4/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.6268 - accuracy: 0.4263 - val_loss: 1.5854 - val_accuracy: 0.4474
# Epoch 5/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.5275 - accuracy: 0.4598 - val_loss: 1.4548 - val_accuracy: 0.4899
# Epoch 6/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.3986 - accuracy: 0.5100 - val_loss: 1.5222 - val_accuracy: 0.5078
# Epoch 7/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.3817 - accuracy: 0.5117 - val_loss: 1.4367 - val_accuracy: 0.5101
# Epoch 8/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.3170 - accuracy: 0.5273 - val_loss: 1.3776 - val_accuracy: 0.5369
# Epoch 9/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.2902 - accuracy: 0.5385 - val_loss: 1.4508 - val_accuracy: 0.5213
# Epoch 10/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.2673 - accuracy: 0.5497 - val_loss: 1.3825 - val_accuracy: 0.5391
# Epoch 11/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.2353 - accuracy: 0.5597 - val_loss: 1.3966 - val_accuracy: 0.5235
# Epoch 12/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1868 - accuracy: 0.5742 - val_loss: 1.3040 - val_accuracy: 0.5548
# Epoch 13/20
# 56/56 [==============================] - 2s 29ms/step - loss: 1.1834 - accuracy: 0.5653 - val_loss: 1.3505 - val_accuracy: 0.5391
# Epoch 14/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1644 - accuracy: 0.5781 - val_loss: 1.3673 - val_accuracy: 0.5526
# Epoch 15/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1519 - accuracy: 0.5831 - val_loss: 1.3420 - val_accuracy: 0.5324
# Epoch 16/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.1228 - accuracy: 0.6049 - val_loss: 1.3937 - val_accuracy: 0.5123
# Epoch 17/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.1628 - accuracy: 0.5815 - val_loss: 1.3426 - val_accuracy: 0.5682
# Epoch 18/20
# 56/56 [==============================] - 2s 32ms/step - loss: 1.1037 - accuracy: 0.5932 - val_loss: 1.3805 - val_accuracy: 0.5459
# Epoch 19/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.1218 - accuracy: 0.6010 - val_loss: 1.4335 - val_accuracy: 0.5369
# Epoch 20/20
# 56/56 [==============================] - 2s 31ms/step - loss: 1.0571 - accuracy: 0.6150 - val_loss: 1.2902 - val_accuracy: 0.5682

# %% [markdown]
# ### **Task 9.6:** Visualizing the results with data augmentation layer

# %%
# visualize_training_results
visualize_training_results(phistory = history, pepochs = epochs)

# %%
# Define a model with LeakyReLU activation
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation=layers.LeakyReLU()),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation=layers.LeakyReLU()),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation=layers.LeakyReLU()),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),# adding 20% dropout to avoid overfit
  layers.Flatten(),
  layers.Dense(128, activation=layers.LeakyReLU()),
  layers.Dense(num_classes, name="outputs")
])

# Model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_2 (Flatten)         (None, 30976)             0
#
#  dense_3 (Dense)             (None, 128)               3965056
#
#  outputs (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model with Stochastic Gradient Descent (SGD) optimizer and SparseCategoricalCrossentropy lossfunction
model.compile(optimizer= keras.optimizers.SGD(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Fit the model
epochs = 30
history = model.fit(
  x =  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 4s 40ms/step - loss: 2.0440 - accuracy: 0.2031 - val_loss: 2.0127 - val_accuracy: 0.2192
# Epoch 2/30
# 56/56 [==============================] - 2s 39ms/step - loss: 2.0064 - accuracy: 0.2377 - val_loss: 1.9935 - val_accuracy: 0.2260
# Epoch 3/30
# 56/56 [==============================] - 2s 36ms/step - loss: 1.9739 - accuracy: 0.2718 - val_loss: 1.9358 - val_accuracy: 0.2864
# Epoch 4/30
# 56/56 [==============================] - 2s 36ms/step - loss: 1.9291 - accuracy: 0.2807 - val_loss: 1.9139 - val_accuracy: 0.2394
# Epoch 5/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.8912 - accuracy: 0.3052 - val_loss: 1.8026 - val_accuracy: 0.3579
# Epoch 6/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.8589 - accuracy: 0.3253 - val_loss: 1.9876 - val_accuracy: 0.2931
# Epoch 7/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.8052 - accuracy: 0.3510 - val_loss: 1.8332 - val_accuracy: 0.2998
# Epoch 8/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.7843 - accuracy: 0.3393 - val_loss: 1.8564 - val_accuracy: 0.3490
# Epoch 9/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.7638 - accuracy: 0.3638 - val_loss: 1.6445 - val_accuracy: 0.4139
# Epoch 10/30
# 56/56 [==============================] - 2s 37ms/step - loss: 1.7730 - accuracy: 0.3711 - val_loss: 1.9697 - val_accuracy: 0.3199
# Epoch 11/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.7941 - accuracy: 0.3460 - val_loss: 1.7973 - val_accuracy: 0.3848
# Epoch 12/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6811 - accuracy: 0.4051 - val_loss: 1.5565 - val_accuracy: 0.4877
# Epoch 13/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6727 - accuracy: 0.4107 - val_loss: 1.5714 - val_accuracy: 0.4430
# Epoch 14/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6348 - accuracy: 0.4213 - val_loss: 1.6315 - val_accuracy: 0.4027
# Epoch 15/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.6931 - accuracy: 0.3984 - val_loss: 1.5255 - val_accuracy: 0.4810
# Epoch 16/30
# 56/56 [==============================] - 2s 37ms/step - loss: 1.5995 - accuracy: 0.4364 - val_loss: 1.8223 - val_accuracy: 0.3602
# Epoch 17/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.5966 - accuracy: 0.4297 - val_loss: 1.8800 - val_accuracy: 0.3065
# Epoch 18/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6063 - accuracy: 0.4330 - val_loss: 1.5273 - val_accuracy: 0.4765
# Epoch 19/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.5135 - accuracy: 0.4587 - val_loss: 1.9655 - val_accuracy: 0.3244
# Epoch 20/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.5221 - accuracy: 0.4559 - val_loss: 1.5928 - val_accuracy: 0.4251
# Epoch 21/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.5169 - accuracy: 0.4710 - val_loss: 1.4232 - val_accuracy: 0.5145
# Epoch 22/30
# 56/56 [==============================] - 2s 36ms/step - loss: 1.5002 - accuracy: 0.4654 - val_loss: 1.4381 - val_accuracy: 0.5123
# Epoch 23/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.4887 - accuracy: 0.4682 - val_loss: 1.4857 - val_accuracy: 0.4743
# Epoch 24/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4479 - accuracy: 0.4771 - val_loss: 1.7181 - val_accuracy: 0.3960
# Epoch 25/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4512 - accuracy: 0.4961 - val_loss: 1.3866 - val_accuracy: 0.5123
# Epoch 26/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.4471 - accuracy: 0.4805 - val_loss: 1.4171 - val_accuracy: 0.5280
# Epoch 27/30
# 56/56 [==============================] - 2s 35ms/step - loss: 1.4007 - accuracy: 0.5006 - val_loss: 1.3088 - val_accuracy: 0.5548
# Epoch 28/30
# 56/56 [==============================] - 2s 37ms/step - loss: 1.3873 - accuracy: 0.5045 - val_loss: 1.3157 - val_accuracy: 0.5347
# Epoch 29/30
# 56/56 [==============================] - 2s 36ms/step - loss: 1.3924 - accuracy: 0.5045 - val_loss: 1.3389 - val_accuracy: 0.5503
# Epoch 30/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1.3819 - accuracy: 0.5022 - val_loss: 1.4268 - val_accuracy: 0.5123

# %% [markdown]
# #### **Question**: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# ### **Findings:** With Data Augmentation and adding dropouts to the output of 3rd maxpooling, we could see that the overfitting is reduce. Now, the training and validation accuracy are closer aligned. Accuracy of the model with traing dataset is ~62% and with validation dataset, it is ~57% with ReLu activation. Accuracy with training data is ~50% and with validation data it is ~51% with LeakyReLU activation. The accuracy of the model is not great, we could try and tweak the model to see if we can improve the performance.

# %% [markdown]
# #### **Task 10:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
# Path list
path_list = list(data_dir_train.glob('*/*.jpg'))
# Lesion list
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob.glob(os.path.join(data_dir_train, '*','*.jpg'))]
# Dataframe of Path and Label
dataframe_dict = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path                 Label
# 0     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  basal cell carcinoma
# 1     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  basal cell carcinoma
# 2     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  basal cell carcinoma
# 3     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  basal cell carcinoma
# 4     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  basal cell carcinoma
# ...                                                 ...                   ...
# 2234  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...        dermatofibroma
# 2235  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...        dermatofibroma
# 2236  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...        dermatofibroma
# 2237  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...        dermatofibroma
# 2238  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...        dermatofibroma
#
# [2239 rows x 2 columns]

# %%
def annotate_plot(plot):
    for bar in plot.patches:
      # x-coordinate: bar.get_x() + bar.get_width() / 2
      # y-coordinate: bar.get_height()
      # free space to be left to make graph pleasing: (0, 8)
      # ha and va stand for the horizontal and vertical alignment
        plot.annotate(format(bar.get_height(), '.0f'), (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha = 'center', va = 'center',
                       size=12,xytext = (0, 8),
                       textcoords = 'offset points')

# %%
dict_num_images = dict()
total_number_training_images = len(list(data_dir_train.glob('*/*.*')))
for i, class_name in enumerate(class_names):
    # Sort the images to makes sure, we get to see the same image every time we execute the code
    dict_num_images[class_name] = len(list(data_dir_train.glob(class_name + '/*.jpg')))

# Dataframe of images counts of different classes in training set
df_image_counts = pd.DataFrame(dict_num_images.items(), columns=['Class Name', 'Count'])
df_image_counts['Proportion to total number of images'] = round(df_image_counts.Count / total_number_training_images, 2)
display(df_image_counts)

# Bar plot of image class count
ax = sns.barplot(x='Class Name', y = 'Count', data = df_image_counts)
ax.set_xticklabels(labels=df_image_counts['Class Name'], rotation = 85)
plt.title('\n\n Class Name bar plot\n', c='g')
plt.xlabel('Class Name',fontsize=10,fontweight='bold',c='b')
plt.ylabel('Images Count',fontsize=10,fontweight='bold',c='b')
annotate_plot(ax)
plt.show()
# Out:
#                    Class Name  Count  Proportion to total number of images
# 0           actinic keratosis    114                                  0.05
# 1        basal cell carcinoma    376                                  0.17
# 2              dermatofibroma     95                                  0.04
# 3                    melanoma    438                                  0.20
# 4                       nevus    357                                  0.16
# 5  pigmented benign keratosis    462                                  0.21
# 6        seborrheic keratosis     77                                  0.03
# 7     squamous cell carcinoma    181                                  0.08
# 8             vascular lesion    139                                  0.06

# %% [markdown]
# #### **Task 11:** Write your findings here:
# #### **Question** - Which class has the least number of samples?
# #### **Answer** - Category 'dermatofibroma' has least number of samples and the count of it is 95, which is 0.04% of the total number of training images provided.
# #### **Question** - Which classes dominate the data in terms proportionate number of samples?
# #### **Answer** - 'pigmented benign keratosis' class dominate the data in terms proportionate number of samples with a proportion of 21% followed by 'melanoma' with a proportion of 20% followed by 'basal cell carcinoma' with a proportion of 17%

# %% [markdown]
# #### **Task 12:** Rectify the class imbalance

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
import Augmentor
print('library - ', Augmentor.__name__,' version ' ,Augmentor.__version__)
# Out:
# library -  Augmentor  version  0.2.12

# %%
path_to_training_dataset = str("/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
for class_name in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + class_name)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7A8635F7F040>: 100%|██████████| 500/500 [00:20<00:00, 24.67 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7A8635E7F7C0>: 100%|██████████| 500/500 [00:20<00:00, 24.26 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7A8635F7F040>: 100%|██████████| 500/500 [00:18<00:00, 26.36 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7A8630233F70>: 100%|██████████| 500/500 [01:41<00:00,  4.91 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7A8634FDBA00>: 100%|██████████| 500/500 [01:40<00:00,  4.97 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7
jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011163.jpg_6007f837-e4c9-4bb7-9399-555aeb82231e.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011121.jpg_7c96cb7f-339f-4696-9feb-82600c6cd225.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011132.jpg_ad43ef9a-4a97-4258-b265-d46690c4b609.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010990.jpg_8682cb1c-422d-47eb-8cce-e048f3811d60.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011169.jpg_6d783738-06f5-428d-b50c-d30077588b1e.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011039.jpg_8baf7d55-898c-48c6-b99a-9b50d072616c.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010898.jpg_657ba73d-dc40-4d2f-854e-071bc5eec107.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011181.jpg_daabccf4-ecc3-4fe8-bfed-0968aade6c4b.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010971.jpg_6792fc5e-9e1f-4757-88e9-d32e34cca478.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011094.jpg_c8acc65b-51ef-43d1-9d3d-e6241329482d.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010909.jpg_a7ca0a59-9cb6-478b-ad41-2e2e0e93886f.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010863.jpg_39b45b2b-8f5d-4ef3-92d7-a9a515dbb1ef.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011158.jpg_c9f1e31b-879f-4bd5-90e4-3a63e0dd6a7d.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011030.jpg_97e44eee-8191-4a87-9644-818898253ec6.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010912.jpg_3c939294-2388-4908-925f-419372578b57.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011139.jpg_ac963a9f-b050-4ba4-b34c-154c872fe2ac.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010866.jpg_16a77423-5967-4623-9063-90cb2d52d89e.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011030.jpg_3013dde5-be0f-48d1-829a-baa1e3d0c870.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010971.jpg_5433ed21-4385-4398-9fed-9ea833569759.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010862.jpg_90377f92-60f8-4d4d-8015-884e6a4315ee.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011032.jpg_553f2085-25fd-43ce-9a47-1341ce681d70.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011158.jpg_96962481-ad47-4018-8b73-e489802b0888.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011137.jpg_4ee9c2da-528e-4798-9939-37dd6c3d22fe.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011012.jpg_00e5bfef-1491-4558-9d92-58ea3e495b89.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010883.jpg_29ced67e-fde6-49a1-9ca7-27303c8d5a18.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011185.jpg_a2375bf9-bcaf-4663-ba0d-d45c0b95a13d.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011135.jpg_5b226c44-5b00-4756-8a0b-bf747d4d6978.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010934.jpg_378346af-613d-49d3-92a5-2a7cde659893.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011013.jpg_12cf03b8-aab4-4900-82df-9ea7e1a9bd47.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011185.jpg_cd6f64fe-18ce-482f-acbe-cfe62573bc58.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011193.jpg_ff48044b-0066-4104-9286-b540bb86243a.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010925.jpg_613b0e95-8bbd-4ee8-b414-aaa13c3afc07.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011012.jpg_27356ff8-87c8-47ae-98ed-9b156d60e4df.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010909.jpg_340e078a-1583-4c0b-a828-1605eb0b43cc.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0010876.jpg_afc630a7-2492-4836-bb52-255b9650486e.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011057.jpg_55f8e062-2f79-47d2-9686-648661c50867.jpg',
#  '/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output/seborrheic keratosis_original_ISIC_0011151.jpg_cc918542-05c6-4af1-87d3-ae5bb2caacec.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  'seborrheic keratosis',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = pd.concat([original_df, df2])

# %%
new_df['Label'].value_counts()
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  actinic keratosis
# 1     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  actinic keratosis
# 2     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  actinic keratosis
# 3     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  actinic keratosis
# 4     /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...  actinic keratosis
# ...                                                 ...                ...
# 4495  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...    vascular lesion
# 4496  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...    vascular lesion
# 4497  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...    vascular lesion
# 4498  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...    vascular lesion
# 4499  /content/gdrive/MyDrive/UpGrad/Skin cancer ISI...    vascular lesion
#
# [6739 rows x 2 columns]

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Task 13**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Task 13.1:** Create a training dataset

# %%
# Get the Train directory with original and augmented images
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/UpGrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Task 13.2:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
num_classes = len(train_ds.class_names)

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### **Task 13.3:** Create the model, include batch normalization layers

# %%
# Define the Model, add batch normalization layer

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 3, padding='same', activation='relu'), # padding='same', which means zero padding with original dimension is retained
  layers.BatchNormalization(),# For normalizing the data input to next layer, which is a pooling layer here. Normalizing the data for training speed, stability, and overall performance.
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),# Flatten the data before giving to fully connected dense layers
  layers.Dense(units = 128),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.2),
  layers.Dense(units = num_classes) #  # dense layer with 9 neuron to predict 9 different categories
])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 16)      448
#
#  batch_normalization (BatchN  (None, 180, 180, 16)     64
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 90, 90, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_3 (Flatten)         (None, 30976)             0
#
#  dense_4 (Dense)             (None, 128)               3965056
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,990,761
# Trainable params: 3,990,281
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# #### **Task 13.4:** Compile your model with Stochastic Gradient Descent (SGD) optimizer and SparseCategoricalCrossentropy lossfunction

# %%
# Compile the model
model.compile(optimizer= keras.optimizers.SGD(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Task 13.5:**  Train the model

# %%
# Fit the model
epochs = 30
history = model.fit(
  x =  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 1518s 2s/step - loss: 1.4825 - accuracy: 0.4618 - val_loss: 2.7527 - val_accuracy: 0.1151
# Epoch 2/30
# 169/169 [==============================] - 7s 42ms/step - loss: 1.0146 - accuracy: 0.6435 - val_loss: 2.0477 - val_accuracy: 0.2071
# Epoch 3/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.7743 - accuracy: 0.7457 - val_loss: 1.2465 - val_accuracy: 0.5642
# Epoch 4/30
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5903 - accuracy: 0.8114 - val_loss: 0.9014 - val_accuracy: 0.7201
# Epoch 5/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.4731 - accuracy: 0.8681 - val_loss: 0.6691 - val_accuracy: 0.7647
# Epoch 6/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.3738 - accuracy: 0.9015 - val_loss: 0.5719 - val_accuracy: 0.8263
# Epoch 7/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.2968 - accuracy: 0.9216 - val_loss: 0.5573 - val_accuracy: 0.8062
# Epoch 8/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.2426 - accuracy: 0.9405 - val_loss: 0.5107 - val_accuracy: 0.8166
# Epoch 9/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.2041 - accuracy: 0.9490 - val_loss: 0.7062 - val_accuracy: 0.7632
# Epoch 10/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.1750 - accuracy: 0.9581 - val_loss: 0.7716 - val_accuracy: 0.7216
# Epoch 11/30
# 169/169 [==============================] - 7s 40ms/step - loss: 0.1488 - accuracy: 0.9614 - val_loss: 0.7398 - val_accuracy: 0.7446
# Epoch 12/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.1339 - accuracy: 0.9694 - val_loss: 0.5596 - val_accuracy: 0.8040
# Epoch 13/30
# 169/169 [==============================] - 7s 43ms/step - loss: 0.1211 - accuracy: 0.9726 - val_loss: 0.5846 - val_accuracy: 0.8092
# Epoch 14/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.1119 - accuracy: 0.9718 - val_loss: 0.9744 - val_accuracy: 0.6912
# Epoch 15/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.0984 - accuracy: 0.9759 - val_loss: 0.5587 - val_accuracy: 0.8077
# Epoch 16/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0907 - accuracy: 0.9796 - val_loss: 0.6600 - val_accuracy: 0.7847
# Epoch 17/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.0852 - accuracy: 0.9783 - val_loss: 0.4833 - val_accuracy: 0.8374
# Epoch 18/30
# 169/169 [==============================] - 7s 43ms/step - loss: 0.0820 - accuracy: 0.9787 - val_loss: 0.8221 - val_accuracy: 0.7238
# Epoch 19/30
# 169/169 [==============================] - 7s 43ms/step - loss: 0.0706 - accuracy: 0.9828 - val_loss: 0.8467 - val_accuracy: 0.7379
# Epoch 20/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0662 - accuracy: 0.9848 - val_loss: 0.4945 - val_accuracy: 0.8352
# Epoch 21/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.0599 - accuracy: 0.9850 - val_loss: 0.9016 - val_accuracy: 0.7090
# Epoch 22/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0599 - accuracy: 0.9853 - val_loss: 0.5185 - val_accuracy: 0.8330
# Epoch 23/30
# 169/169 [==============================] - 7s 40ms/step - loss: 0.0533 - accuracy: 0.9866 - val_loss: 0.5339 - val_accuracy: 0.8255
# Epoch 24/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0518 - accuracy: 0.9876 - val_loss: 0.8341 - val_accuracy: 0.7305
# Epoch 25/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.0521 - accuracy: 0.9863 - val_loss: 0.8437 - val_accuracy: 0.7365
# Epoch 26/30
# 169/169 [==============================] - 7s 42ms/step - loss: 0.0466 - accuracy: 0.9902 - val_loss: 0.5564 - val_accuracy: 0.8218
# Epoch 27/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0454 - accuracy: 0.9878 - val_loss: 0.6263 - val_accuracy: 0.8070
# Epoch 28/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0420 - accuracy: 0.9907 - val_loss: 1.1553 - val_accuracy: 0.6630
# Epoch 29/30
# 169/169 [==============================] - 7s 41ms/step - loss: 0.0396 - accuracy: 0.9904 - val_loss: 0.5295 - val_accuracy: 0.8330
# Epoch 30/30
# 169/169 [==============================] - 7s 40ms/step - loss: 0.0385 - accuracy: 0.9918 - val_loss: 0.8660 - val_accuracy: 0.7491

# %% [markdown]
# #### **Task 13.6:**  Visualize the accuracy and loss

# %%
# Visualize the accuracy
visualize_training_results(phistory = history, pepochs = epochs)

# %% [markdown]
# ### The results of Accuracy and Loss are not great and we can fluctuations in both and the difference of accuracy and loss between Training and Validation is more and model is still overfitting, let's build another model

# %%
# Defining Model

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 3, padding='same', activation=layers.LeakyReLU()), # padding='same', which means zero padding with original dimension is retained
  layers.BatchNormalization(),# For normalizing the data input to next layer, which is a pooling layer here. Normalizing the data for training speed, stability, and overall performance.
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Dropout(0.1), # Dropout 10%
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(), # Normalize the input to next layer
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 128, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  # layers.Dropout(0.1),
  layers.Conv2D(filters = 256, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.1),
  layers.Flatten(),# Flatten the data before giving to fully connected dense layers
  layers.Dense(units = 256),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.20),
  layers.Dense(units = 128),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.25),
  layers.Dense(units = num_classes) #   dense layer with 9 neuron to predict 9 different categories
])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_4 (Batc  (None, 180, 180, 16)     64
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 90, 90, 16)        0
#
#  conv2d_13 (Conv2D)          (None, 90, 90, 32)        4640
#
#  batch_normalization_5 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 22, 22, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 22, 22, 128)      512
#  hNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 11, 11, 256)       295168
#
#  batch_normalization_8 (Batc  (None, 11, 11, 256)      1024
#  hNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten_4 (Flatten)         (None, 6400)              0
#
#  dense_6 (Dense)             (None, 256)               1638656
#
#  batch_normalization_9 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_10 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2,068,841
# Trainable params: 2,067,081
# Non-trainable params: 1,760
# _________________________________________________________________

# %%
### Choosing Stochastic Gradient Descent (SGD) optimiser and SparseCategoricalCrossentropy loss function
model.compile(optimizer= keras.optimizers.SGD(0.2), # Chossing learning_rate = 0.2 as it is giving a best performance
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),# Set from_logits=True to apply softmax activation to output
              metrics=['accuracy'])

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 12s 55ms/step - loss: 1.6436 - accuracy: 0.4004 - val_loss: 2.3576 - val_accuracy: 0.1544
# Epoch 2/30
# 169/169 [==============================] - 8s 48ms/step - loss: 1.2993 - accuracy: 0.5087 - val_loss: 1.5060 - val_accuracy: 0.4365
# Epoch 3/30
# 169/169 [==============================] - 8s 49ms/step - loss: 1.0831 - accuracy: 0.5877 - val_loss: 1.5902 - val_accuracy: 0.4603
# Epoch 4/30
# 169/169 [==============================] - 9s 52ms/step - loss: 0.9018 - accuracy: 0.6619 - val_loss: 0.9678 - val_accuracy: 0.6333
# Epoch 5/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.7434 - accuracy: 0.7155 - val_loss: 1.0678 - val_accuracy: 0.6021
# Epoch 6/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.5994 - accuracy: 0.7674 - val_loss: 0.7792 - val_accuracy: 0.6993
# Epoch 7/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.5088 - accuracy: 0.8045 - val_loss: 0.8195 - val_accuracy: 0.6845
# Epoch 8/30
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4162 - accuracy: 0.8388 - val_loss: 0.7397 - val_accuracy: 0.7409
# Epoch 9/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.3525 - accuracy: 0.8629 - val_loss: 0.5574 - val_accuracy: 0.7862
# Epoch 10/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.2987 - accuracy: 0.8835 - val_loss: 0.5137 - val_accuracy: 0.8330
# Epoch 11/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.2668 - accuracy: 0.8958 - val_loss: 1.0710 - val_accuracy: 0.6964
# Epoch 12/30
# 169/169 [==============================] - 8s 48ms/step - loss: 0.2127 - accuracy: 0.9152 - val_loss: 0.5162 - val_accuracy: 0.8137
# Epoch 13/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.2032 - accuracy: 0.9191 - val_loss: 0.5465 - val_accuracy: 0.8189
# Epoch 14/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.1716 - accuracy: 0.9319 - val_loss: 0.6773 - val_accuracy: 0.7840
# Epoch 15/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.1495 - accuracy: 0.9440 - val_loss: 1.0278 - val_accuracy: 0.7223
# Epoch 16/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.1477 - accuracy: 0.9432 - val_loss: 0.4878 - val_accuracy: 0.8382
# Epoch 17/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.1339 - accuracy: 0.9486 - val_loss: 0.6470 - val_accuracy: 0.8040
# Epoch 18/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.1347 - accuracy: 0.9445 - val_loss: 0.4228 - val_accuracy: 0.8560
# Epoch 19/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.1197 - accuracy: 0.9525 - val_loss: 0.5151 - val_accuracy: 0.8441
# Epoch 20/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.1014 - accuracy: 0.9598 - val_loss: 0.5451 - val_accuracy: 0.8241
# Epoch 21/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.0837 - accuracy: 0.9668 - val_loss: 0.4766 - val_accuracy: 0.8641
# Epoch 22/30
# 169/169 [==============================] - 9s 52ms/step - loss: 0.0919 - accuracy: 0.9633 - val_loss: 0.7983 - val_accuracy: 0.7661
# Epoch 23/30
# 169/169 [==============================] - 10s 61ms/step - loss: 0.0973 - accuracy: 0.9649 - val_loss: 1.4438 - val_accuracy: 0.6667
# Epoch 24/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.0925 - accuracy: 0.9670 - val_loss: 0.4493 - val_accuracy: 0.8782
# Epoch 25/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0808 - accuracy: 0.9692 - val_loss: 0.4525 - val_accuracy: 0.8656
# Epoch 26/30
# 169/169 [==============================] - 9s 52ms/step - loss: 0.0698 - accuracy: 0.9735 - val_loss: 0.4905 - val_accuracy: 0.8679
# Epoch 27/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.0670 - accuracy: 0.9753 - val_loss: 0.5418 - val_accuracy: 0.8545
# Epoch 28/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0552 - accuracy: 0.9796 - val_loss: 0.5142 - val_accuracy: 0.8552
# Epoch 29/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.0631 - accuracy: 0.9761 - val_loss: 0.6132 - val_accuracy: 0.8352
# Epoch 30/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.0525 - accuracy: 0.9802 - val_loss: 0.5593 - val_accuracy: 0.8627

# %%
# Visualize the model results
visualize_training_results(phistory = history, pepochs = epochs)

# %% [markdown]
# ### The results of Accuracy and Loss are getting better. We still see some fluctuations in both with validation data, the difference of accuracy, loss between Training and Validation is comparitively less and the model is doing better aftre 15 epochs, still overfitting a bit. Let's build another model

# %%
# Defining Model

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 3, padding='same', activation=layers.LeakyReLU()), # padding='same', which means zero padding with original dimension is retained
  layers.BatchNormalization(),# For normalizing the data input to next layer, which is a pooling layer here. Normalizing the data for training speed, stability, and overall performance.
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Dropout(0.1), # Dropout 10%
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(), # Normalize the input to next layer
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 128, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  # layers.Dropout(0.1),
  layers.Conv2D(filters = 256, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.20),
  layers.Flatten(),# Flatten the data before giving to fully connected dense layers
  layers.Dense(units = 256),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.20),
  layers.Dense(units = 128),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.25),
  layers.Dense(units = num_classes) #   dense layer with 9 neuron to predict 9 different categories
])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_17 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_11 (Bat  (None, 180, 180, 16)     64
#  chNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 90, 90, 16)        0
#
#  conv2d_18 (Conv2D)          (None, 90, 90, 32)        4640
#
#  batch_normalization_12 (Bat  (None, 90, 90, 32)       128
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_13 (Bat  (None, 45, 45, 64)       256
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 22, 22, 128)       73856
#
#  batch_normalization_14 (Bat  (None, 22, 22, 128)      512
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 11, 11, 256)       295168
#
#  batch_normalization_15 (Bat  (None, 11, 11, 256)      1024
#  chNormalization)
#
#  max_pooling2d_21 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten_5 (Flatten)         (None, 6400)              0
#
#  dense_9 (Dense)             (None, 256)               1638656
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 9)                 1161
#
# =================================================================
# Total params: 2,068,841
# Trainable params: 2,067,081
# Non-trainable params: 1,760
# _________________________________________________________________

# %%
### Choosing Stochastic Gradient Descent (SGD) optimiser and SparseCategoricalCrossentropy loss function
model.compile(optimizer= keras.optimizers.SGD(0.1), # Chossing learning_rate = 0.1 as it is giving a best performance
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True
30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0820 - accuracy: 0.9666 - val_loss: 0.4733 - val_accuracy: 0.8738
# Epoch 28/30
# 169/169 [==============================] - 8s 49ms/step - loss: 0.0683 - accuracy: 0.9757 - val_loss: 0.4220 - val_accuracy: 0.8879
# Epoch 29/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0623 - accuracy: 0.9777 - val_loss: 0.5409 - val_accuracy: 0.8463
# Epoch 30/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0566 - accuracy: 0.9790 - val_loss: 0.4537 - val_accuracy: 0.8604

# %%
# Visualize the model results
visualize_training_results(phistory = history, pepochs = epochs)

# %% [markdown]
# ### The results of Accuracy and Loss are getting better. We still see some fluctuations in both with validation data but fluctuations is better, the difference of accuracy, loss between Training and Validation is comparitively less and the model is doing better aftre 9 epochs, still overfitting a bit. Let's build another model

# %%
# Defining Model

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 3, padding='same', activation=layers.LeakyReLU()), # padding='same', which means zero padding with original dimension is retained
  layers.BatchNormalization(),# For normalizing the data input to next layer, which is a pooling layer here. Normalizing the data for training speed, stability, and overall performance.
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Dropout(0.1), # Dropout 10%
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation=layers.LeakyReLU()),
  layers.BatchNormalization(), # Normalize the input to next layer
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 128, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  # layers.Dropout(0.1),
  layers.Conv2D(filters = 256, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.20),
  layers.Flatten(),# Flatten the data before giving to fully connected dense layers
  layers.Dense(units = 256),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.25),
  layers.Dense(units = 128),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.25),
  layers.Dense(units = num_classes) #   dense layer with 9 neuron to predict 9 different categories
])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_6 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_22 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization_18 (Bat  (None, 180, 180, 16)     64
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 90, 90, 16)        0
#
#  conv2d_23 (Conv2D)          (None, 90, 90, 32)        4640
#
#  batch_normalization_19 (Bat  (None, 90, 90, 32)       128
#  chNormalization)
#
#  max_pooling2d_23 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_20 (Bat  (None, 45, 45, 64)       256
#  chNormalization)
#
#  max_pooling2d_24 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 22, 22, 128)       73856
#
#  batch_normalization_21 (Bat  (None, 22, 22, 128)      512
#  chNormalization)
#
#  max_pooling2d_25 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 11, 11, 256)       295168
#
#  batch_normalization_22 (Bat  (None, 11, 11, 256)      1024
#  chNormalization)
#
#  max_pooling2d_26 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 5, 5, 256)         0
#
#  flatten_6 (Flatten)         (None, 6400)              0
#
#  dense_12 (Dense)            (None, 256)               1638656
#
#  batch_normalization_23 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_5 (Activation)   (None, 256)               0
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  batch_normalization_24 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_6 (Activation)   (None, 128)               0
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 9)                 1161
#
# =================================================================
# Total params: 2,068,841
# Trainable params: 2,067,081
# Non-trainable params: 1,760
# _________________________________________________________________

# %%
### Choosing Stochastic Gradient Descent (SGD) optimiser and SparseCategoricalCrossentropy loss function
model.compile(optimizer= keras.optimizers.SGD(0.1), # Chossing learning_rate = 0.2 as it is giving a best performance
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),# Set from_logits=True to apply softmax activation to output
              metrics=['accuracy'])

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epoch
30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.1104 - accuracy: 0.9560 - val_loss: 0.3773 - val_accuracy: 0.8834
# Epoch 26/30
# 169/169 [==============================] - 8s 50ms/step - loss: 0.0889 - accuracy: 0.9642 - val_loss: 0.4800 - val_accuracy: 0.8619
# Epoch 27/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.0904 - accuracy: 0.9666 - val_loss: 0.5348 - val_accuracy: 0.8463
# Epoch 28/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.0798 - accuracy: 0.9716 - val_loss: 0.3978 - val_accuracy: 0.8812
# Epoch 29/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.0868 - accuracy: 0.9683 - val_loss: 0.3962 - val_accuracy: 0.8768
# Epoch 30/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.0750 - accuracy: 0.9729 - val_loss: 0.7249 - val_accuracy: 0.7988

# %%
# Visualize the model results
visualize_training_results(phistory = history, pepochs = epochs)

# %%
# Defining Model

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)), # With rescaling we are also making sure the values will be in floats for accuracy as well as it helps a bit with performance while training the model as it avoid data type conversion from int to float.
  layers.Conv2D(filters = 16, kernel_size = 5, padding='valid', strides = (2,2), activation=layers.LeakyReLU()), # padding='valid', which means no padding
  layers.BatchNormalization(),# For normalizing the data input to next layer, which is a pooling layer here. Normalizing the data for training speed, stability, and overall performance.
  layers.MaxPooling2D(), # Default pool_size = (2, 2)
  layers.Dropout(0.1), # Dropout 10%
  layers.Conv2D(filters = 32, kernel_size = 3, padding='same', activation=layers.LeakyReLU()),# padding='same', which means zero padding with original dimension is retained
  layers.BatchNormalization(), # Normalize the input to next layer
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 64, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(filters = 128, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  # layers.Dropout(0.1),
  layers.Conv2D(filters = 256, kernel_size = 3, padding='same', activation=layers.ReLU()),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.12),
  layers.Flatten(),# Flatten the data before giving to fully connected dense layers
  layers.Dense(units = 256),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.15),
  layers.Dense(units = 128),
  layers.BatchNormalization(),
  layers.Activation('relu'),
  layers.Dropout(0.25),
  layers.Dense(units = num_classes) #   dense layer with 9 neuron to predict 9 different categories
])


### Choosing Stochastic Gradient Descent (SGD) optimiser and SparseCategoricalCrossentropy loss function
model.compile(optimizer= keras.optimizers.SGD(0.1), # Chossing learning_rate = 0.2 as it is giving a best performance
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),# Set from_logits=True to apply softmax activation to output
              metrics=['accuracy'])
epochs = 30
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs = epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 8s 26ms/step - loss: 1.6341 - accuracy: 0.3908 - val_loss: 1.8885 - val_accuracy: 0.2569
# Epoch 2/30
# 169/169 [==============================] - 3s 21ms/step - loss: 1.2992 - accuracy: 0.5054 - val_loss: 1.6517 - val_accuracy: 0.4001
# Epoch 3/30
# 169/169 [==============================] - 4s 24ms/step - loss: 1.1001 - accuracy: 0.5820 - val_loss: 1.4046 - val_accuracy: 0.4870
# Epoch 4/30
# 169/169 [==============================] - 4s 21ms/step - loss: 0.9090 - accuracy: 0.6547 - val_loss: 2.2085 - val_accuracy: 0.3356
# Epoch 5/30
# 169/169 [==============================] - 4s 21ms/step - loss: 0.7662 - accuracy: 0.7107 - val_loss: 1.0462 - val_accuracy: 0.6169
# Epoch 6/30
# 169/169 [==============================] - 4s 24ms/step - loss: 0
**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# With multiple models we tried,
#
# 1. We can see that the accuracy of the model is increasing steadily with training data with each epoch but is fluctuating a lot in the begining and in the middle with validation data, it starts to get better in the end overall with validation data. But, the model seem to be still overfitting a bit.
#
# 2. We can say that the problem of overfitting has gotten better with rectification of class imbalance by using Augmentor to add more samples across all classes so that none of the classes have very few samples. Rectification of class imbalance helped with model accuracy
#
# 3. We can see that the loss of the model is decreasing steadily with training data with each epoch but is fluctuating a lot in the begining and in the middle with validation data, it starts to get better in the end overall with validation data

# %% [markdown]
# ### **Model we could probably choose:**
# With multiple models we tried, we can choose the below model which is performing pretty good with accuracy and loss. We are getting an Accuracy of 85%+ and the loss curve is going towards zero in the end of training the mode with an epoch size of 30. Model is getting better from 10 epoch and it almost continues till 30th epoch with a minimal fluctuation.
#
# Here is the architecture of the model with balanced data set after augmentation
#
# Sequential([
#
#     - Rescaling(1./255, input_shape=(img_height, img_width, 3))
#     - Conv2D( filters = 16, kernel_size = 3, padding='same', activation=layers.LeakyReLU())
#     - BatchNormalization()
#     - MaxPooling2D()
#     - Dropout(0.1)
#     - Conv2D(filters = 32, kernel_size = 3, padding='same', activation=layers.LeakyReLU())
#     - BatchNormalization()
#     - MaxPooling2D()
#     - Conv2D(filters = 64, kernel_size = 3, padding='same', activation=layers.ReLU())
#     - BatchNormalization()
#     - MaxPooling2D()
#     - layers.Conv2D(filters = 128, kernel_size = 3, padding='same', activation=layers.ReLU())
#     - BatchNormalization()
#     - MaxPooling2D()
#     - Conv2D(filters = 256, kernel_size = 3, padding='same', activation=layers.ReLU())
#     - BatchNormalization()
#     - MaxPooling2D()
#     - Dropout(0.20)
#     - Flatten()
#     - Dense(units = 256)
#     - BatchNormalization()
#     - Activation('relu'),
#     - Dropout(0.25),
#     - Dense(units = 128),
#     - BatchNormalization(),
#     - Activation('relu'),
#     - Dropout(0.25),
#     - Dense(units = num_classes)
#
#
# ])
#
# #### Optimizer is SGD with learning rate 0.1
# #### Loss function is SparseCategoricalCrossentropy with Softmax activation

# %% [markdown]
# ### **Conclusion:**
# With a good amount of experimentation we are able to build a model which gives a validation accuracy of 85%+ by choosing SGD optimizer with 0.1 learning rate, SparseCategoricalCrossentropy as loss function, adding dropout layers, doing batch normalization, applying filters with an ideal kernel size of (3,3) with zero padding to maintain the same dimension of the image to not loose information drastically, with a stride of (1,1)

# %% [markdown]
# #### **Out of curiousity**, let us build an Inception Model and check the accuracy of the model

# %%
# Define Inception module
def inception_module(x, filters):
    conv1x1 = layers.Conv2D(filters[0], (1, 1))(x)
    conv1x1 = layers.BatchNormalization()(conv1x1)
    conv1x1 = layers.Activation('relu')(conv1x1)

    conv3x3 = layers.Conv2D(filters[1], (3, 3), padding='same')(x)
    conv3x3 = layers.BatchNormalization()(conv3x3)
    conv3x3 = layers.Activation('relu')(conv3x3)

    conv5x5 = layers.Conv2D(filters[2], (5, 5), padding='same')(x)
    conv5x5 = layers.BatchNormalization()(conv5x5)
    conv5x5 = layers.Activation('relu')(conv5x5)
    maxpool = layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)

    return layers.concatenate([conv1x1, conv3x3, conv5x5, maxpool], axis=-1) # axis=-1 to concatenate using the last axis, which is the number of channels RGB in the current model

# Build the Inception model
input_layer = layers.Input(shape=(180, 180, 3))

x = layers.Conv2D(64, (7, 7), strides = (2, 2), padding = 'same')(input_layer)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')(x)

x = layers.Conv2D(192, (3, 3), padding = 'same')(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = layers.MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')(x)

# Apply Inception modules
x = inception_module(x, [64, 128, 32])
x = inception_module(x, [128, 192, 96])
x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

# Add fully connected layers
# x = layers.Dropout(0.2)(x)
x = layers.Flatten()(x)
x = layers.Dense(1024, activation = 'relu')(x)
output_layer = layers.Dense(9, activation = 'softmax')(x)

# Create the model
inception_model = keras.models.Model(inputs = input_layer, outputs = output_layer)

# Compile and train the model
inception_model.compile(optimizer = 'SGD', loss = 'SparseCategoricalCrossentropy', metrics = ['accuracy'])

# %%
# Model summary
inception_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv2d_58 (Conv2D)             (None, 90, 90, 64)   9472        ['input_3[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 90, 90, 64)  256         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 90, 90, 64)   0           ['batch_normalization_62[0][0]']
#
#  max_pooling2d_52 (MaxPooling2D  (None, 45, 45, 64)  0           ['activation_29[0][0]']
#  )
#
#  conv2d_59 (Conv2D)             (None, 45, 45, 192)  110784      ['max_pooling2d_52[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 45, 45, 192)  768        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 45, 45, 192)  0           ['batch_normalization_63[0][0]']
#
#  max_pooling2d_53 (MaxPooling2D  (None, 23, 23, 192)  0          ['activation_30[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 23, 23, 64)   12352       ['max_pooling2d_53[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 23, 23, 128)  221312      ['max_pooling2d_53[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 23, 23, 32)   153632      ['max_pooling2d_53[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 23, 23, 64)  256         ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_65 (BatchN  (None, 23, 23, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 23, 23, 32)  128         ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 23, 23, 64)   0           ['batch_normalization_64[0][0]']
#
#  activation_32 (Activation)     (None, 23, 23, 128)  0           ['batch_normalization_65[0][0]']
#
#  activation_33 (Activation)     (None, 23, 23, 32)   0           ['batch_normalization_66[0][0]']
#
#  max_pooling2d_54 (MaxPooling2D  (None, 23, 23, 192)  0          ['max_pooling2d_53[0][0]']
#  )
#
#  concatenate_4 (Concatenate)    (None, 23, 23, 416)  0           ['activation_31[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'max_pooling2d_54[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 23, 23, 128)  53376       ['concatenate_4[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 23, 23, 192)  719040      ['concatenate_4[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 23, 23, 96)   998496      ['concatenate_4[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 23, 23, 128)  512        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 23, 23, 192)  768        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 23, 23, 96)  384         ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 23, 23, 128)  0           ['batch_normalization_67[0][0]']
#
#  activation_35 (Activation)     (None, 23, 23, 192)  0           ['batch_normalization_68[0][0]']
#
#  activation_36 (Activation)     (None, 23, 23, 96)   0           ['batch_normalization_69[0][0]']
#
#  max_pooling2d_55 (MaxPooling2D  (None, 23, 23, 416)  0          ['concatenate_4[0][0]']
#  )
#
#  concatenate_5 (Concatenate)    (None, 23, 23, 832)  0           ['activation_34[0][0]',
#                                                                   'activation_35[0][0]',
#                                                                   'activation_36[0][0]',
#                                                                   'max_pooling2d_55[0][0]']
#
#  max_pooling2d_56 (MaxPooling2D  (None, 12, 12, 832)  0          ['concatenate_5[0][0]']
#  )
#
#  flatten_12 (Flatten)           (None, 119808)       0           ['max_pooling2d_56[0][0]']
#
#  dense_28 (Dense)               (None, 1024)         122684416   ['flatten_12[0][0]']
#
#  dense_29 (Dense)               (None, 9)            9225        ['dense_28[0][0]']
#
# ==================================================================================================
# Total params: 124,975,689
# Trainable params: 124,973,897
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# Fit the model
history = inception_model.fit(
  train_ds,
  validation_data = val_ds,
  epochs = 40,
  batch_size = 32
)
# Out:
# Epoch 1/40
# 169/169 [==============================] - 18s 92ms/step - loss: 7.7090 - accuracy: 0.2706 - val_loss: 2.1904 - val_accuracy: 0.1856
# Epoch 2/40
# 169/169 [==============================] - 15s 90ms/step - loss: 1.5402 - accuracy: 0.4102 - val_loss: 1.5499 - val_accuracy: 0.4284
# Epoch 3/40
# 169/169 [==============================] - 15s 89ms/step - loss: 1.4000 - accuracy: 0.4572 - val_loss: 1.3055 - val_accuracy: 0.4981
# Epoch 4/40
# 169/169 [==============================] - 15s 89ms/step - loss: 1.3178 - accuracy: 0.4911 - val_loss: 1.2797 - val_accuracy: 0.5115
# Epoch 5/40
# 169/169 [==============================] - 15s 90ms/step - loss: 1.2352 - accuracy: 0.5239 - val_loss: 1.4508 - val_accuracy: 0.4870
# Epoch 6/40
# 169/169 [==============================] - 15s 90ms/step - loss: 1.1872 - accuracy: 0.5388 - val_loss: 1.1124 - val_accuracy: 0.5627
# Epoch 7/40
# 169/169 [==============================] - 15s 90ms/step - loss: 1.1260 - accuracy: 0.5621 - val_loss: 1.6454 - val_accuracy: 0.4328
# Epoch 8/40
# 169/169 [==============================] - 15s 89ms/step - loss: 1.0759 - accuracy: 0.5874 - val_loss: 1.1503 - val_accuracy: 0.5583
# Epoch 9/40
# 169/169 [==============================] - 15s 89ms/step - loss: 1.0276 - accuracy: 0.6050 - val_loss: 1.0164 - val_accuracy: 0.5984
# Epoch 10/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.9766 - accuracy: 0.6244 - val_loss: 1.2031 - val_accuracy: 0.5286
# Epoch 11/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.9386 - accuracy: 0.6461 - val_loss: 0.9771 - val_accuracy: 0.6422
# Epoch 12/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.9122 - accuracy: 0.6502 - val_loss: 1.1027 - val_accuracy: 0.5947
# Epoch 13/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.8214 - accuracy: 0.6849 - val_loss: 2.1465 - val_accuracy: 0.4855
# Epoch 14/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.8294 - accuracy: 0.6797 - val_loss: 1.2650 - val_accuracy: 0.5709
# Epoch 15/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.7801 - accuracy: 0.7031 - val_loss: 0.7354 - val_accuracy: 0.7090
# Epoch 16/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.7611 - accuracy: 0.7209 - val_loss: 0.8305 - val_accuracy: 0.6867
# Epoch 17/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.6758 - accuracy: 0.7437 - val_loss: 1.0696 - val_accuracy: 0.6310
# Epoch 18/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.6887 - accuracy: 0.7430 - val_loss: 1.1199 - val_accuracy: 0.6533
# Epoch 19/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.6250 - accuracy: 0.7569 - val_loss: 0.8196 - val_accuracy: 0.6912
# Epoch 20/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.5700 - accuracy: 0.7832 - val_loss: 0.6816 - val_accuracy: 0.7379
# Epoch 21/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.5329 - accuracy: 0.7960 - val_loss: 0.9558 - val_accuracy: 0.6704
# Epoch 22/40
# 169/169 [==============================] - 16s 93ms/step - loss: 0.4992 - accuracy: 0.8080 - val_loss: 1.0918 - val_accuracy: 0.6540
# Epoch 23/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.4745 - accuracy: 0.8162 - val_loss: 0.7234 - val_accuracy: 0.7439
# Epoch 24/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.4822 - accuracy: 0.8147 - val_loss: 0.7883 - val_accuracy: 0.7320
# Epoch 25/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.4236 - accuracy: 0.8359 - val_loss: 0.6093 - val_accuracy: 0.7758
# Epoch 26/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.3441 - accuracy: 0.8615 - val_loss: 0.6619 - val_accuracy: 0.7394
# Epoch 27/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.3181 - accuracy: 0.8783 - val_loss: 0.6370 - val_accuracy: 0.7639
# Epoch 28/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.4074 - accuracy: 0.8587 - val_loss: 0.8041 - val_accuracy: 0.7283
# Epoch 29/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.3680 - accuracy: 0.8691 - val_loss: 1.1248 - val_accuracy: 0.6266
# Epoch 30/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.3200 - accuracy: 0.8787 - val_loss: 0.4625 - val_accuracy: 0.8278
# Epoch 31/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.2610 - accuracy: 0.8967 - val_loss: 0.5103 - val_accuracy: 0.8174
# Epoch 32/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.2177 - accuracy: 0.9164 - val_loss: 0.4389 - val_accuracy: 0.8255
# Epoch 33/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.2086 - accuracy: 0.9197 - val_loss: 0.6146 - val_accuracy: 0.7966
# Epoch 34/40
# 169/169 [==============================] - 15s 91ms/step - loss: 0.1818 - accuracy: 0.9280 - val_loss: 0.5954 - val_accuracy: 0.8048
# Epoch 35/40
# 169/169 [==============================] - 15s 91ms/step - loss: 0.1746 - accuracy: 0.9312 - val_loss: 0.4303 - val_accuracy: 0.8612
# Epoch 36/40
# 169/169 [==============================] - 15s 90ms/step - loss: 0.1756 - accuracy: 0.9318 - val_loss: 0.5763 - val_accuracy: 0.8062
# Epoch 37/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.5799 - accuracy: 0.8461 - val_loss: 1.6141 - val_accuracy: 0.4469
# Epoch 38/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.9507 - accuracy: 0.6571 - val_loss: 1.0514 - val_accuracy: 0.6281
# Epoch 39/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.5985 - accuracy: 0.7810 - val_loss: 0.6895 - val_accuracy: 0.7713
# Epoch 40/40
# 169/169 [==============================] - 15s 89ms/step - loss: 0.4713 - accuracy: 0.8335 - val_loss: 0.6484 - val_accuracy: 0.7647

# %%
# Visualize the results
visualize_training_results(phistory = history, pepochs = 40)

# %% [markdown]
# ### **Inception Model Conclusion:**
# From the accuracy and loss graph we can say that the inception model is doing pretty good with balanced data set for an epoch size of 35 giving an accuracy of 93% with training data and 86% with validation data. Overall, the difference between training and validation accuracy is pretty close compare to all other models we built above, including losses which are low compared to other models.
